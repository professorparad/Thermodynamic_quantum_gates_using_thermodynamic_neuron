# %%
import os
print(os.getcwd())
# Out:
# /home/adminpc/Desktop/Msc_thesis /Phase2/Thermodynamic_qubit_markovian/Thermodynamic_quantum_gates_using_thermodynamic_neuron/Scripts/Thermodynamic_nueron

# %%
import os
os.chdir("/home/adminpc/Desktop/Msc_thesis /Phase2/Thermodynamic_qubit_markovian/Thermodynamic_quantum_gates_using_thermodynamic_neuron/Scripts/Thermodynamic_nueron")

# %%
import os
import sys

print("Current directory:")
print(os.getcwd())

print("\nPython path:")
for p in sys.path:
    print(p)
# Out:
# Current directory:
# /home/adminpc/Desktop/Msc_thesis /Phase2/Thermodynamic_qubit_markovian/Thermodynamic_quantum_gates_using_thermodynamic_neuron/Scripts/Thermodynamic_nueron
#
# Python path:
# /usr/lib/python312.zip
# /usr/lib/python3.12
# /usr/lib/python3.12/lib-dynload
#
# /home/adminpc/Desktop/Msc_thesis /Phase2/Thermodynamic_qubit_markovian/Thermodynamic_quantum_gates_using_thermodynamic_neuron/.venv/lib/python3.12/site-packages

# %%
import os

print(os.path.exists("config"))
print(os.path.exists("config/parametres.py"))
# Out:
# True
# True
